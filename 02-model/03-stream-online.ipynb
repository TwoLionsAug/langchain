# %% [markdown]
# ## stream调用

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 引入环境变量
load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

message = [
    "你是谁",
    "1+1=?",
]

responses = model.batch(message)

for response in responses:
    print(response)

# %%
from rich import print as rprint

message = [
    "你是谁",
]

responses = model.stream(message)

for response in responses:
    rprint(response)
# Out:
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': ''},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '好的'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '用户'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '问'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '“'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '你是谁'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '”，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '这是一个'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '非常'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '简单的'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '自我介绍'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '问题'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '。'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '用户'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '可能是'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '第一次'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '接触'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '我'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '需要'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '了解'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '我的'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '基本'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '身份'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '和'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '功能'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '。\n\n'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '我需要'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '直接'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '、'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '清晰地'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '说明'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '我是'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '谁'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '、'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '由'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '谁'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '创造'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '、'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '以及'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '我的'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '核心'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '能力'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '。'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '想到了'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '用'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '友好的'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '问候'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '开头'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '然后'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '提供'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '关键'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '信息'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '：'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '名称'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '、'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '创造'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '公司'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '、'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '文本'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '模型'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '属性'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '、'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '知识'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '截止'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '日期'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '、'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '上下文'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '长度'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '、'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '文件'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '处理和'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '联网'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '搜索'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '能力'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '最后'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '以'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '服务'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '意愿'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '结尾'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '并'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '保持'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '开放'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '帮助'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '的态度'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '。\n\n'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '用'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '“'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '你好'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '！'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '我是'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': 'Deep'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': 'Se'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': 'ek'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '”'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '开头'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '然后'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '分'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '点'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '或'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '连贯'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '地'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '介绍'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '主要'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '特点'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '语言'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '要'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '流畅'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '自然'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '避免'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '使用'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '列表'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '格式'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '但'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '内部'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '信息'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '要'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '组织'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '清晰'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '。'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '最后'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '询问'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '是否需要'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '帮助'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '，'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '让'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '对话'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '可以'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '继续'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={'reasoning_content': '。'},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='你好',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='！',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='我是',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='Deep',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='Se',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='ek',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='，',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='由',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='深度',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='求',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='索',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='公司',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='创造的',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='AI',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='助手',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='。',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='我是一个',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='纯',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='文本',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='模型',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='，',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='知识',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='截止',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='到',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='202',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='5',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='年',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='5',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='月',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='，',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='拥有',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='1',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='M',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='的',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='上下文',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='处理',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='能力',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='，',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='可以',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='一次性',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='处理',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='像',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='《',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='三',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='体',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='》',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='三部',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='曲',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='那样',
# ...
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='能',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='从中',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='读取',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='文字',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='信息',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='进行处理',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='。',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='我还',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='支持',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='联网',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='搜索',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='功能',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='（',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='需要',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='手动',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='开启',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='），',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='以及',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='App',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='端的',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='语音',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='输入',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='。\n\n',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='最',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='棒',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='的是',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='——',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='我',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='完全',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='免费',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='使用',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='！',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='无论是在',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='网页',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='端',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='还是',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='App',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='端',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='，',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='都没有',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='任何',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='收费',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='计划',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='。',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='我会',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='尽力',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='热情',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='、',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='细腻',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='地',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='帮助你',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='解决',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='各种',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='问题',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='。',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='有什么',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='我可以',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='帮',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='你的',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='吗',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='？',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='😊',
#     additional_kwargs={},
#     response_metadata={'model_provider': 'deepseek'},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={},
#     response_metadata={
#         'finish_reason': 'stop',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'model_provider': 'deepseek'
#     },
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 5,
#         'output_tokens': 275,
#         'total_tokens': 280,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 137}
#     },
#     tool_call_chunks=[]
# )
# AIMessageChunk(
#     content='',
#     additional_kwargs={},
#     response_metadata={},
#     id='lc_run--019f3f75-bf1e-72a0-8002-895eb73eb65a',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     tool_call_chunks=[],
#     chunk_position='last'
# )
