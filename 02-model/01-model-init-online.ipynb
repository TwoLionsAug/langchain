# %% [markdown]
# # 调用线上模型

# %%
import os
from dotenv import load_dotenv
from langchain_community.chat_models import ChatZhipuAI, ChatTongyi
from langchain_deepseek import ChatDeepSeek

# 引入环境变量
load_dotenv(override=True)
DEEPSEEK_DEFAULT_MODEL = os.getenv("DEEPSEEK_DEFAULT_MODEL")
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")


llm_deepseek = ChatDeepSeek(
    model = DEEPSEEK_DEFAULT_MODEL,
    api_key = DEEPSEEK_API_KEY,
    base_url = DEEPSEEK_BASE_URL,
)

response = llm_deepseek.invoke("你是什么人？")

print(response)
# Out:
# content='你好！我是 DeepSeek，一个由深度求索公司创造的 AI 助手。我是纯文本模型，擅长回答各种问题、提供信息、进行创作或帮你分析问题。虽然我不支持多模态识别（比如直接识别图片内容），但可以处理你上传的图像、PDF、Word、Excel 等文件，从中提取文字信息来帮你。\n\n我支持联网搜索（需要你在网页或App上手动开启），上下文处理能力高达 1M tokens，可以一次性处理像《三体》三部曲这样的超长文本。最重要的是，我完全免费使用！我的知识截止于 2025 年 5 月。\n\n有什么我可以帮你的吗？尽管问，我会尽力为你解答！😊' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户问“你是什么人”，这是一个很直接的身份询问问题。我需要清晰、友好地介绍自己，让用户知道我是谁、能做什么。\n\n我是DeepSeek，由深度求索公司创造的AI助手。我应该说明我的核心能力和服务范围，比如文本处理、文件支持、联网搜索等，同时强调我的免费属性和知识截止日期。语气要热情、乐于助人，并开放提问空间。\n\n想到了用自我介绍开头，然后列出主要功能和特点，最后以邀请提问结束。这样既回答了问题，又为后续对话铺路。'} response_metadata={'token_usage': {'completion_tokens': 268, 'prompt_tokens': 8, 'total_tokens': 276, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 118, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '9c1bdee2-692f-45dd-a950-90e22977cb12', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f3c81-1ee3-7331-96a4-2738b7374f20-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 268, 'total_tokens': 276, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 118}}

# %% [markdown]
# ## 智谱api调用

# %%
import os
from dotenv import load_dotenv
from langchain_community.chat_models import ChatZhipuAI
# 引入环境变量
load_dotenv(override=True)
ZHIPUAI_DEFAULT_MODEL = os.getenv("ZHIPUAI_DEFAULT_MODEL")
ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")


llm_zhipu= ChatZhipuAI(
    model = "glm-5.1",
    api_key = ZHIPUAI_API_KEY,
    api_base = ZHIPUAI_BASE_URL,
)

response = llm_zhipu.invoke("你是谁")

print(response)

# %% [markdown]
# ## 千问调用

# %%
## 智谱api调用
import os
from dotenv import load_dotenv
from langchain_community.chat_models import ChatTongyi
# 引入环境变量
load_dotenv(override=True)
DAHSCOPE_API_KEY = os.getenv("DAHSCOPE_API_KEY")

llm_zhipu = ChatTongyi(
    model="qwen-plus",
    api_key=DAHSCOPE_API_KEY,
)

response = llm_zhipu.invoke("你是谁")

print(response)
# Out:
# content='你好！我是通义千问（Qwen），阿里巴巴集团旗下的超大规模语言模型。我能够回答问题、创作文字，比如写故事、写公文、写邮件、写剧本、逻辑推理、编程等等，还能表达观点，玩游戏等。如果你有任何问题或需要帮助，欢迎随时告诉我！😊' additional_kwargs={} response_metadata={'model_name': 'qwen-plus', 'finish_reason': 'stop', 'request_id': '95113513-441c-9bb1-ad71-9d701fe74279', 'token_usage': {'input_tokens': 10, 'output_tokens': 66, 'total_tokens': 76, 'prompt_tokens_details': {'cached_tokens': 0}}} id='lc_run--019f3c86-6917-7c33-8732-8081d25b1631-0' tool_calls=[] invalid_tool_calls=[]
